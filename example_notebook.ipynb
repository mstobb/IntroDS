# %% [raw]
# ---
# title: "Example Notebook"
# author: "Michael T. Stobb"
# date: "9/8/2022"
# format:
#   html:
#     code-fold: true
# jupyter: python3
# ---

# %% [markdown]
# ##  Here is a new section
#
# With some body text.

# %%
#| echo: false
import matplotlib.pyplot as plt
import matplotlib as mpl

plt.style.use('seaborn')
mpl.rcParams['figure.dpi'] = 300

# %% [markdown]
# To test if everything is working, see @fig-quadratic.

# %%
#| label: fig-quadratic
#| fig-cap: "A simple quadratic curve."

import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-5,5)
y = x**2

plt.plot(x,y, linewidth=4)
plt.show()

# %% [markdown]
# @fig-quadratic above is a cool demonstration of what the Quatro publishing suite can do using notebook.
